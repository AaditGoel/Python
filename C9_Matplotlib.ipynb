# %% [markdown]
# <a href="https://colab.research.google.com/github/AaditGoel/Python/blob/main/C9_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([1,10])

plt.plot(xpoints,ypoints)

plt.show()

# %% [markdown]
# Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %% [markdown]
# Plotting Without Line
#
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,8])
y = np.array([3,10])

plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Default X-Points
#
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
import matplotlib.pyplot as plt
import numpy as n

y = n.array([1,4,7,9,8,4,5])

plt.plot(y)
plt.show()

# %%
#to mark each point with marker 

import matplotlib.pyplot as plt
import numpy as np 


y = np.array([0,2,4,6,8,10,12])

plt.plot(y,marker = 'o')
plt.show()

# mark with a star use marker='*'

# %% [markdown]
# **Format Strings fmt**
#
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
import matplotlib.pyplot as plt
import numpy as np 


y = np.array([0,2,4,6,8,10,12])

plt.plot(y,'o:r')  # o means circle, r means red and : means dot lining
plt.show()

# %% [markdown]
# Line Syntax	Description
#
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line

# %% [markdown]
# Color Syntax	Description
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White

# %%
# ms is used to indicate the marker size 
 
import matplotlib.pyplot as pt
import numpy as np

y = np.array([2,3,4,5,7,2,7])

pt.plot(y,'o-r',ms=20)
pt.show()

# %%
#mec indicates the marker edge color 
 
import matplotlib.pyplot as pt
import numpy as np

y = np.array([2,3,4,5,7,2,7])

pt.plot(y,'o-r',ms=20,mec='b')
pt.show()

# %%
#mfc indicates the color inside the edge of the marker 
 
import matplotlib.pyplot as pt
import numpy as np

y = np.array([2,3,4,5,7,2,7])

pt.plot(y,'o-r',ms=20,mec='b',mfc='w')
pt.show()

# %% [markdown]
# Properties of lines u can change
#
# linestyle
#
# line color
#
# line width

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2,linestyle=':')
plt.show()

# %% [markdown]
# U can add the following also:
#
# plt.title -----> change fontsize,color,loc
#
# plt.xlabel
#
# plt.ylabel

# %% [markdown]
# Add Grid Lines to a Plot
#
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.array([1,2,3,4,5,6,7,8])
y = np.array([9,8,7,6,5,4,3,2])

plt.xlabel("date")
plt.ylabel("time")
plt.title("timetable",loc='left')
plt.plot(x,y)
plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.array([1,2,3,4,5,6,7,8])
y = np.array([9,8,7,6,5,4,3,2])

plt.xlabel("date")
plt.ylabel("time")
plt.title("timetable",loc='left')
plt.plot(x,y)
plt.grid(axis='x')

plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.array([1,2,3,4,5,6,7,8])
y = np.array([9,8,7,6,5,4,3,2])

plt.xlabel("date")
plt.ylabel("time")
plt.title("timetable",loc='left')
plt.plot(x,y)
plt.grid(color='green',linewidth = 0.5,linestyle = ':')

plt.show()

# %% [markdown]
# The subplot() Function
#
# The subplot() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.
#
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %%
import matplotlib.pyplot as plt 
import numpy as np

x1 = np.array([1,2,3,4,5,6])
y1 = np.array([2,3,4,5,6,7])

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title("SALES")

x2 = np.array([1,2,3,4,5,6])
y2 = np.array([2,3,4,5,6,7])

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title("SALES")

x3 = np.array([1,2,3,4,5,6])
y3 = np.array([2,3,4,5,6,7])

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title("SALES")

x4 = np.array([1,2,3,4,5,6])
y4 = np.array([2,3,4,5,6,7])

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title("SALES")


plt.suptitle("Total sales")
plt.show()

# %% [markdown]
# You can include the colormap in the drawing by including the plt.colorbar() statement:
#
# For single scattered data u can use c argument only not colors and for size use s
#
# For transparency of dots use alpha like alpha = 0.5

# %%
import numpy as np
from numpy import random 
import matplotlib.pyplot as plt 

x = np.random.randint(100,size = [1,10])
y = np.random.randint(100, size = [1,10])

colors = np.random.randint(100,size=[1,10])
sizes = np.random.randint(100,size=[1,10])

plt.scatter(x,y,c = colors , s = sizes, alpha = 0.5)

plt.show()

# %% [markdown]
# On the same basis we can make histogram and bar graphs with different prop's like size, color etc.
#
# Pie charts can also be made.However,pis has more features as compared to others.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# As you can see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
# By default the plotting of the first wedge starts from the x-axis and move counterclockwise:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ("bmw","audi","Maruti","Voolkswagen")


plt.pie(y,labels = mylabels)
plt.show()

# %% [markdown]
# Start Angle
#
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ("bmw","audi","Maruti","Voolkswagen")


plt.pie(y,labels = mylabels,startangle = 90)
plt.show()

# %% [markdown]
# **Explode**
#
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ("bmw","audi","Maruti","Voolkswagen")
myexp = (0.5,0,0,0)

plt.pie(y,labels = mylabels,startangle = 90 , explode = myexp)
plt.show()

# %% [markdown]
# Other - colors and shadow=True

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ("bmw","audi","Maruti","Voolkswagen")
myexp = (0.5,0,0,0)

plt.pie(y,labels = mylabels,startangle = 90 , explode = myexp)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ("bmw","audi","Maruti","Voolkswagen")
myexp = (0.5,0,0,0)

plt.pie(y,labels = mylabels,startangle = 90 , explode = myexp)
plt.legend(title='cars')
plt.show()
